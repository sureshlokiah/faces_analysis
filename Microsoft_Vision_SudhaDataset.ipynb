# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials

from array import array
import os
from PIL import Image
import sys
import time

# %%
###HERE IS THE DOC
## https://docs.microsoft.com/en-us/azure/cognitive-services/computer-vision/quickstarts-sdk/image-analysis-client-library?tabs=visual-studio&pivots=programming-language-python

# %%
subscription_key = "5b244e5d0ba74f388b7aa8ab6df63a3a"
endpoint = "https://ashring.cognitiveservices.azure.com/"

# %%
## This is the image we need to Cycle through from Google Drive

#remote_image_url = "https://upload.wikimedia.org/wikipedia/en/c/c7/Michael_Jordan_crying.jpg"
remote_image_url = 'https://sureshlokiah.github.io/faces_analysis/crying-faces-5.jpeg'

# %%
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

#remote_image_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/landmark.jpg"
#remote_image_url= 'https://sureshlokiah.github.io/faces_analysis/crying%20face%201.jpeg'

def get_image_description():
    '''
    Describe an Image - remote
    This example describes the contents of an image with the confidence score.
    '''
    print("===== Describe an image - remote =====")
    # Call API
    description_results = computervision_client.describe_image(remote_image_url )

    # Get the captions (descriptions) from the response, with confidence level
    print("Description of remote image: ")
    if (len(description_results.captions) == 0):
        print("No description detected.")
    else:
        for caption in description_results.captions:
            print("'{}' with confidence {:.2f}%".format(caption.text, caption.confidence * 100))

def get_image_category():
    '''
    Categorize an Image - remote
    This example extracts (general) categories from a remote image with a confidence score.
    '''
    print("===== Categorize an image - remote =====")
    # Select the visual feature(s) you want.
    remote_image_features = ["categories"]
    # Call API with URL and features
    categorize_results_remote = computervision_client.analyze_image(remote_image_url, remote_image_features)

    # Print results with confidence score
    print("Categories from remote image: ")
    if (len(categorize_results_remote.categories) == 0):
        print("No categories detected.")
    else:
        for category in categorize_results_remote.categories:
            print("'{}' with confidence {:.2f}%".format(category.name, category.score * 100))

def get_image_tags():
    '''
    Tag an Image - remote
    This example returns a tag (key word) for each thing in the image.
    '''
    print("===== Tag an image - remote =====")
    # Call API with remote image
    tags_result_remote = computervision_client.tag_image(remote_image_url)

    # Print results with confidence score
    print("Tags in the remote image: ")
    if (len(tags_result_remote.tags) == 0):
        print("No tags detected.")
    else:
        for tag in tags_result_remote.tags:
            print("'{}' with confidence {:.2f}%".format(tag.name, tag.confidence * 100))

def detect_objects():
    '''
    Detect Objects - remote
    This example detects different kinds of objects with bounding boxes in a remote image.
    '''
    print("===== Detect Objects - remote =====")
    # Get URL image with different objects
    #### remote_image_url_objects = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/objects.jpg"
    remote_image_url_objects = remote_image_url

    # Call API with URL
    detect_objects_results_remote = computervision_client.detect_objects(remote_image_url_objects)

    # Print detected objects results with bounding boxes
    print("Detecting objects in remote image:")
    if len(detect_objects_results_remote.objects) == 0:
        print("No objects detected.")
    else:
        for object in detect_objects_results_remote.objects:
            print("object at location {}, {}, {}, {}".format( \
                object.rectangle.x, object.rectangle.x + object.rectangle.w, \
                object.rectangle.y, object.rectangle.y + object.rectangle.h))

def detect_faces():
    '''
    Detect Faces - remote
    This example detects faces in a remote image, gets their gender and age, 
    and marks them with a bounding box.
    '''
    print("===== Detect Faces - remote =====")
    # Get an image with faces
    ##### remote_image_url_faces = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/faces.jpg"
    remote_image_url_faces = remote_image_url
    # Select the visual feature(s) you want.
    remote_image_features = ["faces"]
    # Call the API with remote URL and features
    detect_faces_results_remote = computervision_client.analyze_image(remote_image_url_faces, remote_image_features)

    # Print the results with gender, age, and bounding box
    print("Faces in the remote image: ")
    if (len(detect_faces_results_remote.faces) == 0):
        print("No faces detected.")
    else:
        for face in detect_faces_results_remote.faces:
            print("'{}' of age {} at location {}, {}, {}, {}".format(face.gender, face.age, \
            face.face_rectangle.left, face.face_rectangle.top, \
            face.face_rectangle.left + face.face_rectangle.width, \
            face.face_rectangle.top + face.face_rectangle.height))

# %%
get_image_description()
get_image_category()
get_image_tags()
detect_objects()
detect_faces()
# Out:
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with purple hair' with confidence 50.92%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 67.58%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 99.01%
# 'person' with confidence 96.12%
# 'neck' with confidence 93.22%
# 'dreadlocks' with confidence 91.14%
# 'chin' with confidence 88.71%
# 'forehead' with confidence 85.80%
# 'human' with confidence 85.32%
# 'hairstyle' with confidence 84.54%
# 'woman' with confidence 55.90%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 123, 548, 8, 337
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 56 at location 223, 95, 383, 255

# %%
import os
from time import sleep

# %%
i = 1
for remote_image_url in open('/Users/suresh/dev/ds/Faces/faces_analysis/images_data.tsv', 'r'):
    print("\n########################################\n")
    print("Counter = " + str(i))
    print("## BEGIN-----> " + remote_image_url)
    
    sleep(3)
    get_image_description()
    sleep(4)
    get_image_category()
    sleep(3)
    get_image_tags()
    sleep(5)
    detect_objects()
    sleep(5)
    detect_faces()
    sleep(2)

    i = i + 1
    
    print("## END-----> " + url)
# Out:
# ########################################
#
# Counter = 1
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%201.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man's head with a large forehead' with confidence 35.82%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 35.16%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 96.89%
# 'forehead' with confidence 91.72%
# 'man' with confidence 89.99%
# 'chin' with confidence 87.44%
# 'cheek' with confidence 85.88%
# 'art' with confidence 55.48%
# 'face' with confidence 48.01%
# 'head' with confidence 43.39%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 23, 181, 22, 226
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 48 at location 82, 84, 201, 204
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 2
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man sleeping with his eyes closed' with confidence 48.63%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.39%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.77%
# 'human face' with confidence 99.51%
# 'skin' with confidence 93.41%
# 'human' with confidence 92.14%
# 'text' with confidence 88.84%
# 'forehead' with confidence 88.08%
# 'wrinkle' with confidence 87.77%
# 'man' with confidence 85.94%
# 'cheek' with confidence 85.31%
# 'indoor' with confidence 76.68%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 0, 219, 0, 219
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 3
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%203.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'graphical user interface' with confidence 59.71%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_young' with confidence 48.05%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'eyelash' with confidence 98.69%
# 'eyebrow' with confidence 97.14%
# 'skin' with confidence 96.53%
# 'human face' with confidence 96.40%
# 'closeup' with confidence 92.83%
# 'lip' with confidence 89.16%
# 'mascara' with confidence 87.82%
# 'forehead' with confidence 87.78%
# 'portrait photography' with confidence 87.70%
# 'organ' with confidence 86.92%
# 'lipstick' with confidence 86.63%
# 'screenshot' with confidence 86.57%
# 'person' with confidence 85.60%
# 'eye liner' with confidence 85.22%
# 'eye shadow' with confidence 85.17%
# 'portrait' with confidence 84.94%
# 'eyes' with confidence 84.70%
# 'cheek' with confidence 84.58%
# 'jaw' with confidence 84.15%
# 'face' with confidence 67.85%
# 'indoor' with confidence 57.05%
# 'girl' with confidence 44.85%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 0, 190, 1, 189
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 4
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%204.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man with a beard' with confidence 45.28%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 83.59%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.83%
# 'wrinkle' with confidence 97.49%
# 'human face' with confidence 97.38%
# 'forehead' with confidence 96.49%
# 'man' with confidence 95.70%
# 'chin' with confidence 95.01%
# 'skin' with confidence 94.64%
# 'jaw' with confidence 93.49%
# 'cheek' with confidence 93.28%
# 'human' with confidence 91.06%
# 'eyebrow' with confidence 90.44%
# 'frown' with confidence 88.81%
# 'lip' with confidence 88.22%
# 'portrait' with confidence 87.44%
# 'moustache' with confidence 87.11%
# 'gentleman' with confidence 87.07%
# 'facial hair' with confidence 86.11%
# 'wearing' with confidence 68.39%
# 'face' with confidence 64.64%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 1, 211, 1, 200
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 42 at location 58, 38, 202, 182
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 5
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%205.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'LeBron James with a white hat' with confidence 39.10%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 65.62%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 98.02%
# 'man' with confidence 97.18%
# 'clothing' with confidence 96.76%
# 'wrinkle' with confidence 93.15%
# 'forehead' with confidence 92.58%
# 'chin' with confidence 92.49%
# 'facial hair' with confidence 88.69%
# 'moustache' with confidence 88.30%
# 'jaw' with confidence 86.86%
# 'cheek' with confidence 85.11%
# 'person' with confidence 83.13%
# 'face' with confidence 71.58%
# 'wearing' with confidence 61.41%
# 'fabric' with confidence 55.20%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 22, 212, 25, 225
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 33 at location 49, 65, 189, 205
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 6
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying-faces-5.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with purple hair' with confidence 50.92%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 67.58%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 99.01%
# 'person' with confidence 96.12%
# 'neck' with confidence 93.22%
# 'dreadlocks' with confidence 91.14%
# 'chin' with confidence 88.71%
# 'forehead' with confidence 85.80%
# 'human' with confidence 85.32%
# 'hairstyle' with confidence 84.54%
# 'woman' with confidence 55.90%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 123, 548, 8, 337
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 56 at location 223, 95, 383, 255
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 7
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%206.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a woman with her hands on her face' with confidence 51.61%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 87.11%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 99.58%
# 'person' with confidence 99.09%
# 'clothing' with confidence 95.20%
# 'wall' with confidence 90.17%
# 'skin' with confidence 89.13%
# 'screenshot' with confidence 88.09%
# 'portrait' with confidence 86.81%
# 'lip' with confidence 84.85%
# 'eyebrow' with confidence 84.57%
# 'indoor' with confidence 76.38%
# 'girl' with confidence 73.54%
# 'woman' with confidence 63.74%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 56, 218, 16, 178
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 28 at location 89, 61, 146, 118
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 8
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20image%206.jpeg
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man with his eyes closed' with confidence 52.98%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 2.34%
# 'people_' with confidence 56.25%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 99.67%
# 'person' with confidence 99.50%
# 'neck' with confidence 97.08%
# 'smile' with confidence 96.44%
# 'wall' with confidence 96.39%
# 'chin' with confidence 96.38%
# 'man' with confidence 96.13%
# 'forehead' with confidence 95.25%
# 'jaw' with confidence 94.34%
# 'cheek' with confidence 91.75%
# 'clothing' with confidence 91.55%
# 'skin' with confidence 90.17%
# 'shoulder' with confidence 89.09%
# 'male person' with confidence 88.14%
# 'eyebrow' with confidence 87.59%
# 'throat' with confidence 85.74%
# 'human' with confidence 84.65%
# 'indoor' with confidence 72.56%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 105, 453, 16, 282
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 28 at location 218, 109, 320, 211
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 9
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%207.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a woman covering her face with her hand' with confidence 64.89%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 1.56%
# 'people_portrait' with confidence 81.64%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.80%
# 'long hair' with confidence 94.75%
# 'skin' with confidence 91.75%
# 'black hair' with confidence 88.77%
# 'photo shoot' with confidence 87.95%
# 'hairstyle' with confidence 87.37%
# 'eyelash' with confidence 87.22%
# 'portrait' with confidence 86.52%
# 'portrait photography' with confidence 85.59%
# 'female person' with confidence 85.50%
# 'lady' with confidence 84.59%
# 'woman' with confidence 82.26%
# 'indoor' with confidence 81.78%
# 'wall' with confidence 73.30%
# 'girl' with confidence 56.83%
# 'hand' with confidence 43.16%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 88, 272, 7, 179
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 10
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%208.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with a braid' with confidence 27.15%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 50.39%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.96%
# 'portrait' with confidence 96.64%
# 'clothing' with confidence 95.18%
# 'human' with confidence 93.67%
# 'human face' with confidence 93.12%
# 'wrinkle' with confidence 89.45%
# 'skin' with confidence 88.97%
# 'mammal' with confidence 84.13%
# 'purple' with confidence 60.04%
# 'wearing' with confidence 56.45%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# No objects detected.
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 11
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%209.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'Iron Eyes Cody with a beard' with confidence 36.25%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 70.31%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 98.72%
# 'person' with confidence 97.14%
# 'text' with confidence 96.99%
# 'forehead' with confidence 95.09%
# 'portrait' with confidence 94.30%
# 'skin' with confidence 91.91%
# 'jaw' with confidence 91.25%
# 'eyebrow' with confidence 91.23%
# 'chin' with confidence 90.74%
# 'wrinkle' with confidence 90.73%
# 'cheek' with confidence 89.86%
# 'human' with confidence 87.59%
# 'face' with confidence 62.12%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 46, 209, 33, 197
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 52 at location 52, 79, 155, 182
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 12
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%2010.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with a large forehead' with confidence 26.42%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 87.11%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'text' with confidence 99.93%
# 'human face' with confidence 98.84%
# 'person' with confidence 96.91%
# 'wrinkle' with confidence 91.98%
# 'skin' with confidence 91.94%
# 'screenshot' with confidence 91.86%
# 'forehead' with confidence 84.93%
# 'clothing' with confidence 84.58%
# 'woman' with confidence 78.64%
# 'portrait' with confidence 51.86%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# No objects detected.
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 61 at location 39, 54, 148, 163
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 13
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%2011.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man wearing a red and white head scarf' with confidence 38.01%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 92.58%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 98.96%
# 'clothing' with confidence 98.08%
# 'person' with confidence 97.84%
# 'wrinkle' with confidence 97.23%
# 'man' with confidence 95.22%
# 'human beard' with confidence 93.95%
# 'human' with confidence 90.95%
# 'forehead' with confidence 90.95%
# 'moustache' with confidence 90.75%
# 'skin' with confidence 89.17%
# 'facial hair' with confidence 88.99%
# 'turban' with confidence 88.51%
# 'cheek' with confidence 86.70%
# 'flesh' with confidence 85.40%
# 'portrait' with confidence 83.21%
# 'wearing' with confidence 69.26%
# 'face' with confidence 68.73%
# 'red' with confidence 57.54%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 42, 236, 6, 194
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 68 at location 54, 27, 192, 165
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 14
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face1.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man with his hand on his face' with confidence 58.47%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.39%
# 'people_' with confidence 51.56%
# 'people_portrait' with confidence 44.14%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.64%
# 'human face' with confidence 99.00%
# 'smoking' with confidence 92.29%
# 'man' with confidence 92.18%
# 'thinking' with confidence 88.51%
# 'indoor' with confidence 88.04%
# 'clothing' with confidence 84.24%
# 'wall' with confidence 72.11%
# 'mouth' with confidence 71.47%
# 'portrait' with confidence 54.09%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 46, 245, 6, 180
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 28 at location 87, 36, 151, 100
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 15
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face2.jpeg
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with the eyes closed' with confidence 42.48%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_young' with confidence 42.19%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 98.84%
# 'person' with confidence 98.72%
# 'skin' with confidence 92.88%
# 'woman' with confidence 83.97%
# 'indoor' with confidence 69.70%
# 'girl' with confidence 61.48%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 26, 215, 1, 168
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 21 at location 76, 44, 166, 134
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 16
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face3.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man with his hands on his face' with confidence 53.70%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.39%
# 'people_portrait' with confidence 73.44%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.74%
# 'human face' with confidence 98.88%
# 'portrait' with confidence 95.09%
# 'forehead' with confidence 93.95%
# 'skin' with confidence 93.67%
# 'wall' with confidence 92.81%
# 'human' with confidence 92.00%
# 'wrinkle' with confidence 91.39%
# 'anxious' with confidence 90.02%
# 'thinking' with confidence 89.64%
# 'worried' with confidence 89.56%
# 'man' with confidence 89.11%
# 'finger' with confidence 88.18%
# 'indoor' with confidence 85.83%
# 'jaw' with confidence 85.62%
# 'eyebrow' with confidence 85.03%
# 'cheek' with confidence 84.23%
# 'glasses' with confidence 64.00%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 63, 217, 0, 169
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 17
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face%204.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with the arms crossed' with confidence 51.19%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 77.73%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.70%
# 'clothing' with confidence 98.94%
# 'human face' with confidence 98.19%
# 'man' with confidence 92.31%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 0, 41, 45, 180
# object at location 90, 276, 13, 176
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 18
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face5.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man with his mouth open and a glass of water in front of him' with confidence 44.81%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 76.95%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.59%
# 'human face' with confidence 98.37%
# 'indoor' with confidence 91.53%
# 'jaw' with confidence 87.90%
# 'wall' with confidence 84.57%
# 'shout' with confidence 84.41%
# 'holding' with confidence 77.61%
# 'portrait' with confidence 66.87%
# 'mouth' with confidence 66.77%
# 'nature' with confidence 63.19%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 94, 297, 5, 164
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 19
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face%206.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with the hands on the head' with confidence 41.04%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 36.72%
# 'people_portrait' with confidence 54.30%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.73%
# 'human face' with confidence 97.69%
# 'neck' with confidence 90.30%
# 'lip' with confidence 89.54%
# 'clothing' with confidence 89.16%
# 'wall' with confidence 87.45%
# 'jaw' with confidence 87.41%
# 'indoor' with confidence 85.85%
# 'redhead' with confidence 85.74%
# 'red hair' with confidence 84.99%
# 'hair' with confidence 58.05%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 4, 210, 10, 177
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 30 at location 115, 44, 175, 104
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 20
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face%207.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with the hands on the face' with confidence 41.12%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_portrait' with confidence 67.97%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.72%
# 'text' with confidence 97.06%
# 'human face' with confidence 93.05%
# 'indoor' with confidence 89.36%
# 'eyelash' with confidence 87.42%
# 'girl' with confidence 86.18%
# 'nail' with confidence 85.95%
# 'finger' with confidence 85.51%
# 'woman' with confidence 79.65%
# 'wall' with confidence 77.05%
# 'holding' with confidence 74.81%
# 'brushing' with confidence 73.36%
# 'mouth' with confidence 63.69%
# 'hair' with confidence 62.30%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 23, 237, 2, 207
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 21
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face%208.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person holding the face' with confidence 42.43%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 41.80%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.88%
# 'human face' with confidence 98.81%
# 'clothing' with confidence 98.04%
# 'outdoor' with confidence 94.18%
# 'young' with confidence 71.19%
# 'boy' with confidence 65.32%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 4, 192, 16, 158
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 22
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20face%209.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with the hand on the face' with confidence 49.94%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.39%
# 'people_portrait' with confidence 41.02%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.50%
# 'skin' with confidence 93.45%
# 'eyelash' with confidence 91.75%
# 'neck' with confidence 91.39%
# 'throat' with confidence 91.36%
# 'human face' with confidence 90.53%
# 'girl' with confidence 86.44%
# 'lip' with confidence 86.19%
# 'lipstick' with confidence 84.72%
# 'woman' with confidence 76.71%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 94, 301, 5, 162
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 32 at location 116, 41, 197, 122
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 23
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/sneezing%20image%2010.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person holding a pencil' with confidence 38.10%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 82.03%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.65%
# 'clothing' with confidence 99.23%
# 'outdoor' with confidence 92.57%
# 'man' with confidence 92.34%
# 'watch' with confidence 92.12%
# 'building' with confidence 90.80%
# 'phone' with confidence 90.31%
# 'human face' with confidence 85.86%
# 'street fashion' with confidence 84.67%
# 'street' with confidence 79.44%
# 'cellphone' with confidence 77.46%
# 'city' with confidence 66.66%
# 'ear' with confidence 66.12%
# 'using' with confidence 57.65%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 35, 77, 113, 159
# object at location 112, 266, 12, 177
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 24
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%201.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'graphical user interface, application' with confidence 96.05%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.39%
# 'people_' with confidence 58.59%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.04%
# 'human face' with confidence 95.64%
# 'skin' with confidence 90.08%
# 'jaw' with confidence 89.83%
# 'tooth' with confidence 86.63%
# 'shout' with confidence 85.42%
# 'clothing' with confidence 84.31%
# 'wall' with confidence 80.00%
# 'indoor' with confidence 68.42%
# 'mouth' with confidence 53.75%
# 'scream' with confidence 44.01%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 68, 219, 9, 167
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 24 at location 118, 24, 170, 76
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 25
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%202.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'graphical user interface' with confidence 61.63%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 90.62%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 97.36%
# 'human face' with confidence 92.95%
# 'clothing' with confidence 89.74%
# 'wall' with confidence 79.39%
# 'fashion' with confidence 53.76%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# No objects detected.
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 26
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%203.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person crying with the hands on the face' with confidence 55.45%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.39%
# 'people_young' with confidence 38.67%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.49%
# 'skin' with confidence 94.59%
# 'human face' with confidence 94.21%
# 'eyelash' with confidence 93.85%
# 'jaw' with confidence 90.50%
# 'lip' with confidence 88.16%
# 'indoor' with confidence 86.68%
# 'tooth' with confidence 85.94%
# 'shout' with confidence 84.12%
# 'wall' with confidence 75.62%
# 'mouth' with confidence 74.26%
# 'woman' with confidence 65.62%
# 'hair' with confidence 52.94%
# 'girl' with confidence 43.96%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 61, 258, 3, 178
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 31 at location 77, 34, 154, 111
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 27
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%204.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'graphical user interface' with confidence 36.71%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.78%
# 'people_' with confidence 64.84%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'human face' with confidence 98.07%
# 'text' with confidence 97.81%
# 'man' with confidence 97.47%
# 'human beard' with confidence 95.64%
# 'person' with confidence 94.54%
# 'facial hair' with confidence 92.93%
# 'moustache' with confidence 91.14%
# 'portrait' with confidence 91.05%
# 'forehead' with confidence 90.66%
# 'jaw' with confidence 88.87%
# 'human' with confidence 86.88%
# 'eyebrow' with confidence 85.69%
# 'cheek' with confidence 84.01%
# 'beard' with confidence 44.76%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 46, 180, 9, 180
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 44 at location 88, 48, 149, 109
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 28
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%205.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man and a woman' with confidence 34.89%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.78%
# 'people_portrait' with confidence 44.92%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 98.50%
# 'text' with confidence 98.31%
# 'human beard' with confidence 88.58%
# 'man' with confidence 85.35%
# 'skin' with confidence 84.37%
# 'indoor' with confidence 82.42%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 0, 183, 73, 205
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 29
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%206.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a man with his hand on his face' with confidence 53.89%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 95.31%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.61%
# 'human face' with confidence 98.91%
# 'shoulder' with confidence 95.44%
# 'elbow' with confidence 95.34%
# 'wall' with confidence 94.29%
# 'neck' with confidence 94.20%
# 'clothing' with confidence 93.89%
# 'muscle' with confidence 93.27%
# 'human' with confidence 89.96%
# 'joint' with confidence 89.48%
# 'man' with confidence 88.12%
# 'male person' with confidence 88.01%
# 'adult' with confidence 87.13%
# 'chest' with confidence 85.55%
# 'wrist' with confidence 84.12%
# 'indoor' with confidence 57.29%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 94, 241, 29, 177
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 30
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%207.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person with the hands on the face' with confidence 47.30%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 84.38%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.80%
# 'indoor' with confidence 98.80%
# 'human face' with confidence 98.29%
# 'wall' with confidence 96.23%
# 'clothing' with confidence 93.07%
# 'black hair' with confidence 91.88%
# 'woman' with confidence 88.80%
# 'skin' with confidence 86.29%
# 'hair' with confidence 59.92%
# 'girl' with confidence 53.74%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 6, 205, 5, 166
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 31
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%208.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a person lying on a bed' with confidence 46.14%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 84.77%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.60%
# 'girl' with confidence 98.13%
# 'indoor' with confidence 97.93%
# 'text' with confidence 97.14%
# 'bed' with confidence 96.83%
# 'human face' with confidence 96.43%
# 'wall' with confidence 93.07%
# 'clothing' with confidence 89.48%
# 'comfort' with confidence 86.65%
# 'furniture' with confidence 86.62%
# 'photo shoot' with confidence 86.04%
# 'pillow' with confidence 84.80%
# 'woman' with confidence 83.45%
# 'sitting' with confidence 70.57%
# 'bedclothes' with confidence 67.03%
# 'boudoir' with confidence 45.84%
# 'fashion' with confidence 42.45%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 13, 165, 15, 169
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 32
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/ywaning%20face%209.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'a woman with her hand on her face' with confidence 53.22%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'people_' with confidence 74.61%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.54%
# 'human face' with confidence 97.43%
# 'clothing' with confidence 94.80%
# 'neck' with confidence 92.30%
# 'girl' with confidence 91.23%
# 'skin' with confidence 89.67%
# 'lip' with confidence 87.69%
# 'wall' with confidence 82.22%
# 'woman' with confidence 74.34%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 8, 156, 16, 178
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Female' of age 20 at location 87, 45, 140, 98
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
#
#
# ########################################
#
# Counter = 33
# ## BEGIN-----> https://sureshlokiah.github.io/faces_analysis/yawning%20face%2010.jpeg
#
# ===== Describe an image - remote =====
# Description of remote image:
# 'graphical user interface, application' with confidence 97.43%
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'others_' with confidence 0.78%
# 'people_' with confidence 58.98%
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'person' with confidence 99.22%
# 'human face' with confidence 98.56%
# 'portrait' with confidence 93.14%
# 'human' with confidence 90.63%
# 'thinking' with confidence 84.23%
# 'hood' with confidence 69.25%
# 'head covering' with confidence 68.77%
# ===== Detect Objects - remote =====
# Detecting objects in remote image:
# object at location 24, 202, 56, 182
# ===== Detect Faces - remote =====
# Faces in the remote image:
# No faces detected.
# ## END-----> https://sureshlokiah.github.io/faces_analysis/crying%20face%202.jpeg
